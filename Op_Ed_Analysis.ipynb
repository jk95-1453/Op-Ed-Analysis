# %% [markdown]
# <a href="https://colab.research.google.com/github/jk95-1453/Op-Ed-Analysis/blob/main/Op_Ed_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
list_of_opinion_pieces = ["How the Muslim Manosphere Exploits Young Men", "How a Japanese Video Games Makes the Case for Halal Courtship", "Is James Gunn Quietly Redrawing Hollywood's Moral Map?", "Why Kennedy's Opinions on Autism Are Dangerous and Dehumanizing", "Why Persona 5: Royal is the Greatest RPG Ever Made", "Stop Blaming Autism. Neil Gaiman and Elon Musk are just Loathseome", "Democrats only have Themselves to Blame for Trump", "You can't understand Islamic extremism if you don't understand Sayyid Qutb", "Southport Attack Exposes the Myth of the Refugee Terrorist", "What We've Learned A Decade After James Foley's Murder", "Blood of Zeus is a Throwback to your Favorite 2000s Anime", "Donny Deutsch Needs to Dial it Back", "Alex Garland's Civil War offers a Warning", "Anti-Zionism is NOT Antisemitism", "Why Autism Speaks fits the bill as a hate group", "The Mirage of Progress: Why France is guilty of sportswashing", "On the irredeemable Henry Kissinger", "Hollywood's Paradox: The illusion of progress in Special Ops: Lioness", "QAnon has gone mainstream with Sound of Freedom", "Stop casting white guys to play Jesus", "Guy Ritchie's The Covenant tries to buck lazy Muslim tropes", "How people with Asperger's are stigmatized"]

# %%
print(list_of_opinion_pieces)
# Out:
# ['How the Muslim Manosphere Exploits Young Men', 'How a Japanese Video Games Makes the Case for Halal Courtship', "Is James Gunn Quietly Redrawing Hollywood's Moral Map?", "Why Kennedy's Opinions on Autism Are Dangerous and Dehumanizing", 'Why Persona 5: Royal is the Greatest RPG Ever Made', 'Stop Blaming Autism. Neil Gaiman and Elon Musk are just Loathseome', 'Democrats only have Themselves to Blame for Trump', "You can't understand Islamic extremism if you don't understand Sayyid Qutb", 'Southport Attack Exposes the Myth of the Refugee Terrorist', "What We've Learned A Decade After James Foley's Murder", 'Blood of Zeus is a Throwback to your Favorite 2000s Anime', 'Donny Deutsch Needs to Dial it Back', "Alex Garland's Civil War offers a Warning", 'Anti-Zionism is NOT Antisemitism', 'Why Autism Speaks fits the bill as a hate group', 'The Mirage of Progress: Why France is guilty of sportswashing', 'On the irredeemable Henry Kissinger', "Hollywood's Paradox: The illusion of progress i
# ...

# %%
list_of_opinion_pieces_mentioning_religion = ["Guy Ritchie's The Covenant tries to buck lazy Muslim tropes", "Stop casting white guys to play Jesus", "Hollywood's paradox: The illusion of progress in Special Ops: Lioness", "The mirage of progress: Why France is guilty of sportswashing", "Anti-Zionism is NOT antisemitism", "What we've learned a decade after James Foley's murder", "Southport attack exposes the myth of the refugee terrorist", "Kamala Harris is guilty of purplewashing. I'm still voting for her", "You can't understand Islamic extremism if you don't understand Sayyid Qutb", "Is James Gunn quietly redrawing Hollywood's moral map?", "How the Muslim Manosphere exploits young men"]

# %%
print(list_of_opinion_pieces_mentioning_religion)
# Out:
# ["Guy Ritchie's The Covenant tries to buck lazy Muslim tropes", 'Stop casting white guys to play Jesus', "Hollywood's paradox: The illusion of progress in Special Ops: Lioness", 'The mirage of progress: Why France is guilty of sportswashing', 'Anti-Zionism is NOT antisemitism', "What we've learned a decade after James Foley's murder", 'Southport attack exposes the myth of the refugee terrorist', "Kamala Harris is guilty of purplewashing. I'm still voting for her", "You can't understand Islamic extremism if you don't understand Sayyid Qutb", "Is James Gunn quietly redrawing Hollywood's moral map?", 'How the Muslim Manosphere exploits young men']

# %%
list_of_opinion_pieces_mentioning_hollywood = ["Guy Ritchie's The Covenant tries to buck lazy Muslim tropes", "Stop casting white guys to play Jesus", "QAnon has gone mainstream with Sound of Freedom", "Hollywood's paradox: The illusion of progress in Special Ops Lioness", "Alex Garland's Civil War offers a warning", "Is James Gunn quietly redrawing Hollywood's moral map?"]

# %%
print(list_of_opinion_pieces_mentioning_hollywood)
# Out:
# ["Guy Ritchie's The Covenant tries to buck lazy Muslim tropes", 'Stop casting white guys to play Jesus', 'QAnon has gone mainstream with Sound of Freedom', "Hollywood's paradox: The illusion of progress in Special Ops Lioness", "Alex Garland's Civil War offers a warning", "Is James Gunn quietly redrawing Hollywood's moral map?"]

# %%
list_of_opinion_pieces_mentioning_autism = ["How people with Asperger's are stigmatized", "Why Autism Speaks fits the bill as a hate group", "Donny Deutsch needs to dial it back", "Stop blaming Autism. Neil Gaiman and Elon Musk are just loathsome", "How the Muslim manosphere exploits young men"]

# %%
print(list_of_opinion_pieces_mentioning_autism)
# Out:
# ["How people with Asperger's are stigmatized", 'Why Autism Speaks fits the bill as a hate group', 'Donny Deutsch needs to dial it back', 'Stop blaming Autism. Neil Gaiman and Elon Musk are just loathsome', 'How the Muslim manosphere exploits young men']

# %%
list_of_opinion_pieces_mentioning_video_games = ["How people with Asperger's are stigmatized", "Why Persona 5: Royal is the greatest RPG ever made", "How a Japanese video game makes the case for halal courtship"]

# %%
print(list_of_opinion_pieces_mentioning_video_games)
# Out:
# ["How people with Asperger's are stigmatized", 'Why Persona 5: Royal is the greatest RPG ever made', 'How a Japanese video game makes the case for halal courtship']

# %%
number_of_opinion_pieces = [25]

# %%
print(number_of_opinion_pieces)
# Out:
# [25]

# %%
number_of_opinion_pieces_mentioning_religion = [11]

# %%
print(number_of_opinion_pieces_mentioning_religion)
# Out:
# [11]

# %%
number_of_opinion_pieces_mentioning_hollywood = [6]

# %%
print(number_of_opinion_pieces_mentioning_hollywood)
# Out:
# [6]

# %%
number_of_opinion_pieces_mentioning_autism = [5]

# %%
print(number_of_opinion_pieces_mentioning_autism)
# Out:
# [5]

# %%
number_of_opinion_pieces_mentioning_video_games = [3]

# %%
print(number_of_opinion_pieces_mentioning_video_games)
# Out:
# [3]

# %%
list_of_numbers = [25, 11, 6, 5, 3]

# %%
print(list_of_numbers)
# Out:
# [25, 11, 6, 5, 3]

# %%
a = [25, 11, 6, 5, 3]

# %%
avg = sum(a)/len(a)

# %%
print(avg)
# Out:
# 10.0
